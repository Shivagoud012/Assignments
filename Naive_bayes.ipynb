# %%
import pandas as pd
df1=pd.read_csv("D:/data science/Assignments/Naive_bayes/SalaryData_Train.csv")
df2=pd.read_csv("D:/data science/Assignments/Naive_bayes/SalaryData_Test.csv")
import warnings
warnings.filterwarnings('ignore')

# %%
df1
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
df2
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
df1.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# ...

# %%
df2.head()
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# ...

# %%
df1.tail()
# Out:
#        age      workclass    education  educationno        maritalstatus  \
# 30156   27        Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40        Private      HS-grad            9   Married-civ-spouse
# 30158   58        Private      HS-grad            9              Widowed
# 30159   22        Private      HS-grad            9        Never-married
# 30160   52   Self-emp-inc      HS-grad            9   Married-civ-spouse
#
#                occupation relationship    race      sex  capitalgain  \
# 30156        Tech-support         Wife   White   Female            0
# 30157   Machine-op-inspct      Husband   White     Male            0
# 30158        Adm-clerical    Unmarried   White   Female            0
# 30159        Adm-clerical    Own-child   White     Male            0
# 30160     Exec-managerial         Wife   White   Female        15024
#
#        capitalloss  hoursperweek          native  Salary
# ...

# %%
df2.tail()
# Out:
#        age      workclass   education  educationno        maritalstatus  \
# 15055   33        Private   Bachelors           13        Never-married
# 15056   39        Private   Bachelors           13             Divorced
# 15057   38        Private   Bachelors           13   Married-civ-spouse
# 15058   44        Private   Bachelors           13             Divorced
# 15059   35   Self-emp-inc   Bachelors           13   Married-civ-spouse
#
#              occupation    relationship                 race      sex  \
# 15055    Prof-specialty       Own-child                White     Male
# 15056    Prof-specialty   Not-in-family                White   Female
# 15057    Prof-specialty         Husband                White     Male
# 15058      Adm-clerical       Own-child   Asian-Pac-Islander     Male
# 15059   Exec-managerial         Husband                White     Male
#
#        capitalgain  capitalloss  hoursperweek          native  Salary
# ...

# %%
df1.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  30161.000000  30161.000000  30161.000000  30161.000000  30161.000000
# mean      38.438115     10.121316   1092.044064     88.302311     40.931269
# std       13.134830      2.550037   7406.466611    404.121321     11.980182
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       47.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   4356.000000     99.000000

# %%
df2.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  15060.000000  15060.000000  15060.000000  15060.000000  15060.000000
# mean      38.768327     10.112749   1120.301594     89.041899     40.951594
# std       13.380676      2.558727   7703.181842    406.283245     12.062831
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       48.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   3770.000000     99.000000

# %%
df=pd.concat([df1,df2],ignore_index=True)
df
# Out:
#        age          workclass   education  educationno        maritalstatus  \
# 0       39          State-gov   Bachelors           13        Never-married
# 1       50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2       38            Private     HS-grad            9             Divorced
# 3       53            Private        11th            7   Married-civ-spouse
# 4       28            Private   Bachelors           13   Married-civ-spouse
# ...    ...                ...         ...          ...                  ...
# 45216   33            Private   Bachelors           13        Never-married
# 45217   39            Private   Bachelors           13             Divorced
# 45218   38            Private   Bachelors           13   Married-civ-spouse
# 45219   44            Private   Bachelors           13             Divorced
# 45220   35       Self-emp-inc   Bachelors           13   Married-civ-spouse
#
# ...

# %%
df.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  45221.000000  45221.000000  45221.000000  45221.000000  45221.000000
# mean      38.548086     10.118463   1101.454700     88.548617     40.938038
# std       13.217981      2.552909   7506.511295    404.838249     12.007640
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       47.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   4356.000000     99.000000

# %%
import seaborn as sns
sns.set_style(style="darkgrid")
sns.pairplot(df)

# %%
import seaborn as sns
print(sns.countplot(x="Salary", data=df))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
import seaborn as sns
print(sns.countplot(x="Salary",hue="sex",data=df))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
print(sns.countplot(x="Salary",hue="native",data=df))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
print(sns.countplot(x="Salary",hue="maritalstatus",data=df))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
print(sns.countplot(x="Salary",hue="hoursperweek",data=df))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in range(1,14):
    df.iloc[:,i]=le.fit_transform(df.iloc[:,i])

# %%
import matplotlib.pyplot as plt
X=df.iloc[:,:14]
Y=df["Salary"]
for i in X:
    sns.distplot(X[i])
    plt.figure()

# %%
X
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           12              4           0
# 1       50          4          9           12              2           3
# 2       38          2         11            8              0           5
# 3       53          2          1            6              2           5
# 4       28          2          9           12              2           9
# ...    ...        ...        ...          ...            ...         ...
# 45216   33          2          9           12              4           9
# 45217   39          2          9           12              0           9
# 45218   38          2          9           12              2           9
# 45219   44          2          9           12              0           0
# 45220   35          3          9           12              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

from sklearn.naive_bayes import MultinomialNB
MNB = MultinomialNB()
MNB.fit(X_train,Y_train)

Y_pred_train = MNB.predict(X_train)
Y_pred_test = MNB.predict(X_test)
from sklearn.metrics import accuracy_score

acc1 = accuracy_score(Y_train,Y_pred_train).round(2)
print("naive bayes model Training score:" , acc1)
acc2 = accuracy_score(Y_test,Y_pred_test).round(2)
print("naive bayes model Test score:" , acc2)
# Out:
# naive bayes model Training score: 0.78
# naive bayes model Test score: 0.78

# %%
df1
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
import seaborn as sns
sns.set_style(style="darkgrid")
sns.pairplot(df1)

# %%
import seaborn as sns
sns.set_style(style="darkgrid")
sns.pairplot(df2)

# %%
for i in range(1,14):
    df1.iloc[:,i]=le.fit_transform(df1.iloc[:,i])

# %%
for i in range(1,14):
    df2.iloc[:,i]=le.fit_transform(df2.iloc[:,i])

# %%
import matplotlib.pyplot as plt
X1=df1.iloc[:,:14]
Y1=df1["Salary"]
for i in X:
    sns.distplot(X1[i])
    plt.figure()

# %%
import matplotlib.pyplot as plt
X2=df2.iloc[:,:14]
Y2=df2["Salary"]
for i in X:
    sns.distplot(X2[i])
    plt.figure()

# %%
X1_train=df1.iloc[:,:14]
X2_test=df2.iloc[:,:14]
Y1_train=df1["Salary"]
Y2_test=df2["Salary"]

# %%
from sklearn.naive_bayes import MultinomialNB
MNB = MultinomialNB()
MNB.fit(X1_train,Y1_train)
# Out:
# MultinomialNB()

# %%
from sklearn.naive_bayes import MultinomialNB
MNB = MultinomialNB()
MNB.fit(X2_test,Y2_test)
# Out:
# MultinomialNB()

# %%
Y1_pred_train = MNB.predict(X1_train)
Y2_pred_test = MNB.predict(X2_test)

# %%
from sklearn.metrics import accuracy_score

acc1 = accuracy_score(Y1_train,Y1_pred_train).round(2)
print("naive bayes model Training score:" , acc1)
acc2 = accuracy_score(Y2_test,Y2_pred_test).round(2)
print("naive bayes model Test score:" , acc2)
# Out:
# naive bayes model Training score: 0.78
# naive bayes model Test score: 0.78
