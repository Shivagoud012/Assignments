# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("D:/data science/Assignments/Multi_Linear_regression/50_startups.csv")
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
df.isna()
# Out:
#     R&D Spend  Administration  Marketing Spend  State  Profit
# 0       False           False            False  False   False
# 1       False           False            False  False   False
# 2       False           False            False  False   False
# 3       False           False            False  False   False
# 4       False           False            False  False   False
# 5       False           False            False  False   False
# 6       False           False            False  False   False
# 7       False           False            False  False   False
# 8       False           False            False  False   False
# 9       False           False            False  False   False
# 10      False           False            False  False   False
# 11      False           False            False  False   False
# 12      False           False            False  False   False
# 13      False           False            False  False   False
# ...

# %%
df.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
df['R&D Spend'].describe()
# Out:
# count        50.000000
# mean      73721.615600
# std       45902.256482
# min           0.000000
# 25%       39936.370000
# 50%       73051.080000
# 75%      101602.800000
# max      165349.200000
# Name: R&D Spend, dtype: float64

# %%
df['Administration'].describe()
# Out:
# count        50.000000
# mean     121344.639600
# std       28017.802755
# min       51283.140000
# 25%      103730.875000
# 50%      122699.795000
# 75%      144842.180000
# max      182645.560000
# Name: Administration, dtype: float64

# %%
df['Marketing Spend'].describe()
# Out:
# count        50.000000
# mean     211025.097800
# std      122290.310726
# min           0.000000
# 25%      129300.132500
# 50%      212716.240000
# 75%      299469.085000
# max      471784.100000
# Name: Marketing Spend, dtype: float64

# %%
df['State'].describe()
# Out:
# count           50
# unique           3
# top       New York
# freq            17
# Name: State, dtype: object

# %%
print(df.boxplot(column="R&D Spend"))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
print(df.boxplot(column="Administration"))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
print(df.boxplot(column="Marketing Spend"))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'R&D Spend'}>,
#         <AxesSubplot:title={'center':'Administration'}>],
#        [<AxesSubplot:title={'center':'Marketing Spend'}>,
#         <AxesSubplot:title={'center':'Profit'}>]], dtype=object)

# %%
df.corr()
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
df.rename(columns={"R&D Spend":"RandD_spend","Marketing Spend":"Marketing_Spend"},inplace=True)

# %%
df.rename(columns={"R&D Spend":"RandD_spend","Marketing Spend":"Marketing_Spend"},inplace=True)

# %%
df.rename(columns={"R&D_Spend":"RandD_spend","Marketing Spend":"Marketing_Spend"},inplace=True)

# %%
df
# Out:
#     RandD_spend  Administration  Marketing_Spend       State     Profit
# 0     165349.20       136897.80        471784.10    New York  192261.83
# 1     162597.70       151377.59        443898.53  California  191792.06
# 2     153441.51       101145.55        407934.54     Florida  191050.39
# 3     144372.41       118671.85        383199.62    New York  182901.99
# 4     142107.34        91391.77        366168.42     Florida  166187.94
# 5     131876.90        99814.71        362861.36    New York  156991.12
# 6     134615.46       147198.87        127716.82  California  156122.51
# 7     130298.13       145530.06        323876.68     Florida  155752.60
# 8     120542.52       148718.95        311613.29    New York  152211.77
# 9     123334.88       108679.17        304981.62  California  149759.96
# 10    101913.08       110594.11        229160.95     Florida  146121.95
# 11    100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["State"]=le.fit_transform(df["State"])
df
# Out:
#     RandD_spend  Administration  Marketing_Spend  State     Profit
# 0     165349.20       136897.80        471784.10      2  192261.83
# 1     162597.70       151377.59        443898.53      0  191792.06
# 2     153441.51       101145.55        407934.54      1  191050.39
# 3     144372.41       118671.85        383199.62      2  182901.99
# 4     142107.34        91391.77        366168.42      1  166187.94
# 5     131876.90        99814.71        362861.36      2  156991.12
# 6     134615.46       147198.87        127716.82      0  156122.51
# 7     130298.13       145530.06        323876.68      1  155752.60
# 8     120542.52       148718.95        311613.29      2  152211.77
# 9     123334.88       108679.17        304981.62      0  149759.96
# 10    101913.08       110594.11        229160.95      1  146121.95
# 11    100671.96        91790.61        249744.55      0  144259.40
# 12     93863.75       127320.38        249839.44      1  141585.52
# ...

# %%
X=df[["RandD_spend","Administration","Marketing_Spend","State"]]
Y=df["Profit"]
import seaborn as sns
sns.pairplot(df)

# %%
X=df.iloc[:,0:4]
Y=df["Profit"]
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
l=lr.fit(X,Y)
y_pred=lr.predict(X)
y_pred
# Out:
# array([192502.76441569, 189182.66604537, 182150.95841893, 173677.49061831,
#        172142.80063001, 163561.20795755, 158138.91212502, 160023.60415542,
#        151721.15820902, 154909.30674   , 135510.37351801, 135597.51300262,
#        129138.8786306 , 127510.97126516, 149550.343104  , 146214.62758875,
#        116937.89389796, 130170.79803397, 129015.0689683 , 115613.22799121,
#        116662.14204417, 117296.98376962, 114706.94317288, 109996.45606057,
#        113341.03973173, 102259.49040895, 110600.45227028, 114385.5581763 ,
#        101659.11459807, 101772.02860061,  99451.95339849,  97664.71273399,
#         99023.17676297,  97914.37368769,  89060.01706124,  90488.40342916,
#         75284.11129779,  89641.23303238,  69673.28063294,  83750.15676874,
#         74836.31063948,  74800.89157002,  70640.77104461,  60142.13119236,
#         64631.11685137,  47625.13881299,  56162.99623609,  46509.56395631,
#         49146.57324723,  48234.27349509])

# %%
from sklearn.metrics import mean_squared_error,r2_score
import numpy as np
r2=r2_score(Y,y_pred)
mse=mean_squared_error(Y,y_pred)
print("r2 value",r2)
print("Root mean squared error",np.sqrt(mse))
# Out:
# r2 value 0.9507462044842656
# Root mean squared error 8855.325573724913

# %%
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
for i in X:
    sns.distplot(X[i])
    plt.figure()

# %%
df.corr()
# Out:
#                  RandD_spend  Administration  Marketing_Spend     State  \
# RandD_spend         1.000000        0.241955         0.724248  0.104685
# Administration      0.241955        1.000000        -0.032154  0.011847
# Marketing_Spend     0.724248       -0.032154         1.000000  0.077670
# State               0.104685        0.011847         0.077670  1.000000
# Profit              0.972900        0.200717         0.747766  0.101796
#
#                    Profit
# RandD_spend      0.972900
# Administration   0.200717
# Marketing_Spend  0.747766
# State            0.101796
# Profit           1.000000

# %% [markdown]
# # From the correlation table we can see that there is a strong correlation between 	R&D Spend and 	Marketing Spend

# %%
import matplotlib.pyplot as plt
plt.scatter(x=df["RandD_spend"],y=df["Profit"],color="black")
plt.scatter(x=df["Administration"],y=df["Profit"],color="green")
plt.scatter(x=df["State"],y=df["Profit"],color="blue")
plt.scatter(x=df["Marketing_Spend"],y=df["Profit"],color="blue")

# %%
x1=df[["RandD_spend","Administration","State"]]
y1=df["Profit"]
from sklearn.linear_model import LinearRegression 
lr=LinearRegression()
lr.fit(x1,y1)
lr.intercept_
lr.coef_
y_pred=lr.predict(x1)

from sklearn.metrics import mean_squared_error,r2_score
msc=mean_squared_error(y1,y_pred)
print(msc.round(3))
print(np.sqrt(msc).round(3))
print("r square", r2_score(y1,y_pred).round(3))
vif=1/(1-r2_score(y1,y_pred).round(3))
vif
# Out:
# 83086348.825
# 9115.171
# r square 0.948
# 19.230769230769212

# %%
x2=df[["Marketing_Spend","Administration","State"]]
y2=df["Profit"]
from sklearn.linear_model import LinearRegression 
lr=LinearRegression()
lr.fit(x2,y2)
lr.intercept_
lr.coef_
y_pred=lr.predict(x2)

from sklearn.metrics import mean_squared_error,r2_score
msc=mean_squared_error(y2,y_pred)
print(msc.round(3))
print(np.sqrt(msc).round(3))
print("r square", r2_score(y2,y_pred).round(3))
vif=1/(1-r2_score(y2,y_pred).round(3))
vif
# Out:
# 618732090.033
# 24874.326
# r square 0.611
# 2.570694087403599

# %%
from sklearn.preprocessing import StandardScaler
SS=StandardScaler()
ss= SS.fit_transform(X)

# %%
Y
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
from sklearn.model_selection import train_test_split

train_error = []
test_error = []
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
from sklearn.model_selection import train_test_split

for i in range(1,100):
    X_train,X_test,Y_train,Y_test = train_test_split(ss,Y, test_size=0.3, random_state=(i))
    LR = LinearRegression()
    LR.fit(X_train,Y_train)
    Y_pred_train = LR.predict(X_train)
    Y_pred_test = LR.predict(X_test)
    train_error.append(np.sqrt(mean_squared_error(Y_train,Y_pred_train)))
    test_error.append(np.sqrt(mean_squared_error(Y_test,Y_pred_test)))
print("root mean squared error ",np.mean(train_error))
print("root mean squared error ",np.mean(test_error))
# Out:
# root mean squared error  8716.113998924404
# root mean squared error  9510.316724289753

# %%
df
# Out:
#     RandD_spend  Administration  Marketing_Spend  State     Profit
# 0     165349.20       136897.80        471784.10      2  192261.83
# 1     162597.70       151377.59        443898.53      0  191792.06
# 2     153441.51       101145.55        407934.54      1  191050.39
# 3     144372.41       118671.85        383199.62      2  182901.99
# 4     142107.34        91391.77        366168.42      1  166187.94
# 5     131876.90        99814.71        362861.36      2  156991.12
# 6     134615.46       147198.87        127716.82      0  156122.51
# 7     130298.13       145530.06        323876.68      1  155752.60
# 8     120542.52       148718.95        311613.29      2  152211.77
# 9     123334.88       108679.17        304981.62      0  149759.96
# 10    101913.08       110594.11        229160.95      1  146121.95
# 11    100671.96        91790.61        249744.55      0  144259.40
# 12     93863.75       127320.38        249839.44      1  141585.52
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
mm=MinMaxScaler()
MM=mm.fit_transform(df)
MM=pd.DataFrame(MM)
MM=MM.rename(columns={0:"RandD_spend",1:"Administration",2:"Marketing_Spend",3:"State",4:"Profit"})
X=MM.iloc[:,0:4]
Y=MM["Profit"]
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
M=lr.fit(MM,Y)
y_pred=lr.predict(MM)
y_pred
MM
# Out:
#     RandD_spend  Administration  Marketing_Spend  State    Profit
# 0      1.000000        0.651744         1.000000    1.0  1.000000
# 1      0.983359        0.761972         0.940893    0.0  0.997355
# 2      0.927985        0.379579         0.864664    0.5  0.993178
# 3      0.873136        0.512998         0.812235    1.0  0.947292
# 4      0.859438        0.305328         0.776136    0.5  0.853171
# 5      0.797566        0.369448         0.769126    1.0  0.801382
# 6      0.814128        0.730161         0.270710    0.0  0.796490
# 7      0.788018        0.717457         0.686493    0.5  0.794407
# 8      0.729018        0.741733         0.660500    1.0  0.774468
# 9      0.745906        0.436929         0.646443    0.0  0.760661
# 10     0.616351        0.451506         0.485733    0.5  0.740175
# 11     0.608845        0.308364         0.529362    0.0  0.729686
# 12     0.567670        0.578836         0.529563    0.5  0.714629
# ...

# %%
import statsmodels.formula.api as smf

# %%
ss1 = smf.ols('Profit~RandD_spend+Administration+Marketing_Spend+State',data=df).fit()

# %%
ss1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     217.2
# Date:                Mon, 24 Apr 2023   Prob (F-statistic):           8.51e-29
# Time:                        10:44:43   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1061.
# Df Residuals:                      45   BIC:                             1070.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
ss2 = smf.ols('Profit~RandD_spend',data=df).fit()
ss2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     849.8
# Date:                Mon, 24 Apr 2023   Prob (F-statistic):           3.50e-32
# Time:                        10:44:43   Log-Likelihood:                -527.44
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      48   BIC:                             1063.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    4.903e+04   2537.897     19.320      0.000    4.39e+04    5.41e+04
# ...

# %%
ss3 = smf.ols('Profit~Marketing_Spend+Administration+State',data=df).fit()
ss3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.611
# Model:                            OLS   Adj. R-squared:                  0.586
# Method:                 Least Squares   F-statistic:                     24.12
# Date:                Mon, 24 Apr 2023   Prob (F-statistic):           1.58e-09
# Time:                        10:44:44   Log-Likelihood:                -577.03
# No. Observations:                  50   AIC:                             1162.
# Df Residuals:                      46   BIC:                             1170.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
ss4 = smf.ols('Profit~Marketing_Spend+Administration+State',data=MM).fit()
ss4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.611
# Model:                            OLS   Adj. R-squared:                  0.586
# Method:                 Least Squares   F-statistic:                     24.12
# Date:                Mon, 24 Apr 2023   Prob (F-statistic):           1.58e-09
# Time:                        10:44:45   Log-Likelihood:                 27.332
# No. Observations:                  50   AIC:                            -46.66
# Df Residuals:                      46   BIC:                            -39.02
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
import statsmodels.api as sm
sm.graphics.influence_plot(ss1)

# %%
df1=df.drop(df.index[[19,49,45]],axis=0)

# %%
ssn = smf.ols('Profit~RandD_spend+Administration+Marketing_Spend+State',data=df1).fit()

# %%
ssn.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.966
# Model:                            OLS   Adj. R-squared:                  0.963
# Method:                 Least Squares   F-statistic:                     297.1
# Date:                Mon, 24 Apr 2023   Prob (F-statistic):           3.36e-30
# Time:                        10:44:48   Log-Likelihood:                -482.80
# No. Observations:                  47   AIC:                             975.6
# Df Residuals:                      42   BIC:                             984.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
profit_predict = ssn.predict(df1[['RandD_spend','Administration','Marketing_Spend','State']])
profit_predict
# Out:
# 0     190517.353018
# 1     190779.394892
# 2     181907.721513
# 3     171525.606830
# 4     171862.233286
# 5     161610.531386
# 6     157748.904616
# 7     159559.427432
# 8     149509.285650
# 9     156448.208687
# 10    135063.736575
# 11    137300.496200
# 12    129044.850945
# 13    129364.238037
# 14    148750.812450
# 15    143793.785899
# 16    119297.287314
# 17    128403.640624
# 18    129399.638068
# 20    119384.350666
# 21    116089.667647
# 22    115615.119430
# 23    111129.983843
# 24    110921.756827
# 25    103834.805532
# 26    109954.676342
# 27    113870.871266
# 28    101028.931694
# 29     99236.968642
# 30     98857.259869
# 31     95085.193798
# 32     99860.581392
# 33     98593.059715
# 34     91707.178401
# 35     89490.546383
# 36     76500.435452
# 37     92488.712712
# 38     69230.944915
# 39     86476.541156
# 40     77718.109797
# 41     75822.312959
# 42     73497.524511
# 43     58379.263428
# 44     66348.080540
# 46     58964.761187
# ...

# %%
sm.graphics.plot_partregress_grid(ssn)
# Out:
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
qqplot=sm.qqplot(ss1.resid,line='q') 
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
qqplot=sm.qqplot(ssn.resid,line='q') # line = 45 to draw the diagnoal line
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %% [markdown]
# # Corolla data set

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("D:/data science/Assignments/Multi_Linear_regression/ToyotaCorolla.csv",encoding="ISO-8859-1")
df
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  ...  \
# ...

# %%
df=df.loc[:,["Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight"]]
df
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 9 columns]

# %%
df.head()
# Out:
#    Price  Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0  13500         23  46986  90  2000      3      5            210    1165
# 1  13750         23  72937  90  2000      3      5            210    1165
# 2  13950         24  41711  90  2000      3      5            210    1165
# 3  14950         26  48000  90  2000      3      5            210    1165
# 4  13750         30  38500  90  2000      3      5            210    1170

# %%
df.tail()
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114

# %%
df["Age_08_04"].describe()
# Out:
# count    1436.000000
# mean       55.947075
# std        18.599988
# min         1.000000
# 25%        44.000000
# 50%        61.000000
# 75%        70.000000
# max        80.000000
# Name: Age_08_04, dtype: float64

# %%
df["Price"].describe()
# Out:
# count     1436.000000
# mean     10730.824513
# std       3626.964585
# min       4350.000000
# 25%       8450.000000
# 50%       9900.000000
# 75%      11950.000000
# max      32500.000000
# Name: Price, dtype: float64

# %%
df["KM"].describe()
# Out:
# count      1436.000000
# mean      68533.259749
# std       37506.448872
# min           1.000000
# 25%       43000.000000
# 50%       63389.500000
# 75%       87020.750000
# max      243000.000000
# Name: KM, dtype: float64

# %%
df["HP"].describe()
# Out:
# count    1436.000000
# mean      101.502089
# std        14.981080
# min        69.000000
# 25%        90.000000
# 50%       110.000000
# 75%       110.000000
# max       192.000000
# Name: HP, dtype: float64

# %%
df["cc"].describe()
# Out:
# count     1436.00000
# mean      1576.85585
# std        424.38677
# min       1300.00000
# 25%       1400.00000
# 50%       1600.00000
# 75%       1600.00000
# max      16000.00000
# Name: cc, dtype: float64

# %%
df.corr()
# Out:
#                   Price  Age_08_04        KM        HP        cc     Doors  \
# Price          1.000000  -0.876590 -0.569960  0.314990  0.126389  0.185326
# Age_08_04     -0.876590   1.000000  0.505672 -0.156622 -0.098084 -0.148359
# KM            -0.569960   0.505672  1.000000 -0.333538  0.102683 -0.036197
# HP             0.314990  -0.156622 -0.333538  1.000000  0.035856  0.092424
# cc             0.126389  -0.098084  0.102683  0.035856  1.000000  0.079903
# Doors          0.185326  -0.148359 -0.036197  0.092424  0.079903  1.000000
# Gears          0.063104  -0.005364  0.015023  0.209477  0.014629 -0.160141
# Quarterly_Tax  0.219197  -0.198431  0.278165 -0.298432  0.306996  0.109363
# Weight         0.581198  -0.470253 -0.028598  0.089614  0.335637  0.302618
#
#                   Gears  Quarterly_Tax    Weight
# Price          0.063104       0.219197  0.581198
# Age_08_04     -0.005364      -0.198431 -0.470253
# KM             0.015023       0.278165 -0.028598
# ...

# %%
df.dtypes
# Out:
# Price            int64
# Age_08_04        int64
# KM               int64
# HP               int64
# cc               int64
# Doors            int64
# Gears            int64
# Quarterly_Tax    int64
# Weight           int64
# dtype: object

# %%
df.isna()
# Out:
#       Price  Age_08_04     KM     HP     cc  Doors  Gears  Quarterly_Tax  \
# 0     False      False  False  False  False  False  False          False
# 1     False      False  False  False  False  False  False          False
# 2     False      False  False  False  False  False  False          False
# 3     False      False  False  False  False  False  False          False
# 4     False      False  False  False  False  False  False          False
# ...     ...        ...    ...    ...    ...    ...    ...            ...
# 1431  False      False  False  False  False  False  False          False
# 1432  False      False  False  False  False  False  False          False
# 1433  False      False  False  False  False  False  False          False
# 1434  False      False  False  False  False  False  False          False
# 1435  False      False  False  False  False  False  False          False
#
#       Weight
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...

# %%
df.isna().sum()
# Out:
# Price            0
# Age_08_04        0
# KM               0
# HP               0
# cc               0
# Doors            0
# Gears            0
# Quarterly_Tax    0
# Weight           0
# dtype: int64

# %%
X=df.iloc[:,1:9]
Y=df["Price"]
X
# Out:
#       Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0            23  46986   90  2000      3      5            210    1165
# 1            23  72937   90  2000      3      5            210    1165
# 2            24  41711   90  2000      3      5            210    1165
# 3            26  48000   90  2000      3      5            210    1165
# 4            30  38500   90  2000      3      5            210    1170
# ...         ...    ...  ...   ...    ...    ...            ...     ...
# 1431         69  20544   86  1300      3      5             69    1025
# 1432         72  19000   86  1300      3      5             69    1015
# 1433         71  17016   86  1300      3      5             69    1015
# 1434         70  16916   86  1300      3      5             69    1015
# 1435         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 8 columns]

# %%
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
for i in X:
    sns.distplot(X[i])
    plt.figure()

# %%
print(df.boxplot(column="Age_08_04"))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
print(df.boxplot(column="KM"))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
print(df.boxplot(column="HP"))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
print(df.boxplot(column="cc"))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
print(df.boxplot(column="Weight"))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
import seaborn as sns
sns.pairplot(df)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
l=lr.fit(X,Y)
y_pred=lr.predict(X)
y_pred
# Out:
# array([16812.58050518, 16272.35518581, 16800.73245987, ...,
#         8454.29800682,  8578.03812148, 10402.43833285])

# %%
from sklearn.metrics import mean_squared_error,r2_score
import numpy as np
r2=r2_score(Y,y_pred)
mse=mean_squared_error(Y,y_pred)
print("r2 value",r2)
print("Root mean squared error",np.sqrt(mse))
# Out:
# r2 value 0.8637627463428192
# Root mean squared error 1338.2584236201512

# %%
df.corr()
# Out:
#                   Price  Age_08_04        KM        HP        cc     Doors  \
# Price          1.000000  -0.876590 -0.569960  0.314990  0.126389  0.185326
# Age_08_04     -0.876590   1.000000  0.505672 -0.156622 -0.098084 -0.148359
# KM            -0.569960   0.505672  1.000000 -0.333538  0.102683 -0.036197
# HP             0.314990  -0.156622 -0.333538  1.000000  0.035856  0.092424
# cc             0.126389  -0.098084  0.102683  0.035856  1.000000  0.079903
# Doors          0.185326  -0.148359 -0.036197  0.092424  0.079903  1.000000
# Gears          0.063104  -0.005364  0.015023  0.209477  0.014629 -0.160141
# Quarterly_Tax  0.219197  -0.198431  0.278165 -0.298432  0.306996  0.109363
# Weight         0.581198  -0.470253 -0.028598  0.089614  0.335637  0.302618
#
#                   Gears  Quarterly_Tax    Weight
# Price          0.063104       0.219197  0.581198
# Age_08_04     -0.005364      -0.198431 -0.470253
# KM             0.015023       0.278165 -0.028598
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(x=df["Age_08_04"],y=df["Price"],color="black")

# %%
plt.scatter(x=df["HP"],y=df["Price"],color="blue")

# %%
plt.scatter(x=df["cc"],y=df["Price"],color="red")

# %%
plt.scatter(x=df["Doors"],y=df["Price"],color="yellow")

# %%
plt.scatter(x=df["Gears"],y=df["Price"],color="pink")

# %%
x1=df[["Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax"]]
y1=df["Price"]
from sklearn.linear_model import LinearRegression 
lr=LinearRegression()
lr.fit(x1,y1)
lr.intercept_
lr.coef_
y_pred=lr.predict(x1)

from sklearn.metrics import mean_squared_error,r2_score
msc=mean_squared_error(y1,y_pred)
print(msc.round(3))
print(np.sqrt(msc).round(3))
print("r square", r2_score(y1,y_pred).round(3))
vif=1/(1-r2_score(y1,y_pred).round(3))
vif
# Out:
# 2107415.583
# 1451.694
# r square 0.84
# 6.249999999999999

# %%
x1=df[["Age_08_04","KM","HP","cc","Doors","Gears","Weight"]]
y1=df["Price"]
from sklearn.linear_model import LinearRegression 
lr=LinearRegression()
lr.fit(x1,y1)
lr.intercept_
lr.coef_
y_pred=lr.predict(x1)

from sklearn.metrics import mean_squared_error,r2_score
msc=mean_squared_error(y1,y_pred)
print(msc.round(3))
print(np.sqrt(msc).round(3))
print("r square", r2_score(y1,y_pred).round(3))
vif=1/(1-r2_score(y1,y_pred).round(3))
vif
# Out:
# 1802340.645
# 1342.513
# r square 0.863
# 7.2992700729927

# %%
from sklearn.preprocessing import StandardScaler
SS=StandardScaler()
ss= SS.fit_transform(X)

# %%
train_error = []
test_error = []
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
from sklearn.model_selection import train_test_split

for i in range(1,100):
    X_train,X_test,Y_train,Y_test = train_test_split(ss,Y, test_size=0.3, random_state=(i))
    LR = LinearRegression()
    LR.fit(X_train,Y_train)
    Y_pred_train = LR.predict(X_train)
    Y_pred_test = LR.predict(X_test)
    train_error.append(np.sqrt(mean_squared_error(Y_train,Y_pred_train)))
    test_error.append(np.sqrt(mean_squared_error(Y_test,Y_pred_test)))
print("root mean squared error ",np.mean(train_error))
print("root mean squared error ",np.mean(test_error))
# Out:
# root mean squared error  1321.1029831493572
# root mean squared error  1663.6380764021678

# %%
import statsmodels.formula.api as smf

# %%
ss1 = smf.ols('Price~Age_08_04+KM+HP+cc+Doors+Gears+Weight',data=df).fit()

# %%
ss1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     1284.
# Date:                Sun, 23 Apr 2023   Prob (F-statistic):               0.00
# Time:                        23:53:36   Log-Likelihood:                -12380.
# No. Observations:                1436   AIC:                         2.478e+04
# Df Residuals:                    1428   BIC:                         2.482e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -7116.7137   1318.946     -5.396      0.000   -9703.993   -4529.435
# ...

# %%
ss2 = smf.ols('Price~Age_08_04+KM+HP+cc+Doors+Gears+Weight+Quarterly_Tax',data=df).fit()

# %%
ss2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     849.8
# Date:                Sun, 23 Apr 2023   Prob (F-statistic):           3.50e-32
# Time:                        23:54:55   Log-Likelihood:                -527.44
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      48   BIC:                             1063.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    4.903e+04   2537.897     19.320      0.000    4.39e+04    5.41e+04
# ...

# %%
ss3 = smf.ols('Price~Age_08_04+KM+HP+cc+Doors+Gears+Weight+Quarterly_Tax',data=df).fit()

# %%
ss3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.864
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     1131.
# Date:                Sun, 23 Apr 2023   Prob (F-statistic):               0.00
# Time:                        23:57:14   Log-Likelihood:                -12376.
# No. Observations:                1436   AIC:                         2.477e+04
# Df Residuals:                    1427   BIC:                         2.482e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
import statsmodels.api as sm
sm.graphics.influence_plot(ss2)

# %%
df1=df.drop(df.index[[49,14]],axis=0)

# %%
ssn = smf.ols('Price~Age_08_04+KM+HP+cc+Doors+Gears+Weight+Quarterly_Tax',data=df1).fit()

# %%
ssn.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     1119.
# Date:                Mon, 24 Apr 2023   Prob (F-statistic):               0.00
# Time:                        00:03:28   Log-Likelihood:                -12355.
# No. Observations:                1434   AIC:                         2.473e+04
# Df Residuals:                    1425   BIC:                         2.478e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
profit_predict = ssn.predict(df1[["Age_08_04","KM","HP","cc","Doors","Gears","Weight","Quarterly_Tax"]])
profit_predict
# Out:
# 0       16807.559772
# 1       16263.488642
# 2       16796.594288
# 3       16421.628226
# 4       16218.987410
#             ...
# 1431     8827.692382
# 1432     8326.552378
# 1433     8489.705151
# 1434     8613.359252
# 1435    10406.245646
# Length: 1434, dtype: float64

# %%
sm.graphics.plot_partregress_grid(ssn)
# Out:
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
qqplot=sm.qqplot(ss2.resid,line='q')
plt.title("Normal Q-Q plot of residuals")
plt.show()
